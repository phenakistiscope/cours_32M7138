# %% [markdown]
# ### Manipuler des images avec Python: partie 1
#
# ## Du pixel aux images - 32M7138
#
# *Printemps 2024 - Université de Genève*
#
# *Adrien Jeanrenaud (adrien.jeanrenaud@unige.ch)*

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Manipulations des images partie 1</b> : jusque là nous avons manipulé les images une par. Dès aujourd'hui, nous allons voir comment manipuler les images en quatité, leur appliquer des transformations et extraire des informations:
# </div>
#
# ## **Plan du cours**
#
# > **Importer des images**
# > * Rappel sur les chemins
# > * Une fonction pour importer un dossier
# > * Une fonction pour importer seulement des images
#
# > **Extraire des informations**
# > * Rappel sur les informations
# > * Extraires des informations en boucles
# > * Visualiser les informations
#
# > **Travailler avec des données textuelles et visuelles**
# > * Importer et visualiser un tableau de données
# > * Télécharger les données visuelles
# > * Lier les données visuelles et textuelles
# > * Viualiser les informations

# %% [markdown]
# ## 1. Importer des images
#
# Pour importer des images, il faut revenir aux cours précédents et se rappeler comment naviguer sur notre machine et cibler un dossier. Ensuite, il nous faut stocker les images dans une varaible. Le but final est de créer une fonction utilisable en tous temps.
#
# ### Rappel sur les chemins
#
# La librairie "os" permet de naviguer sur notre machine et cibler un dossier avec des images.

# %%
import os

# %%
# dans quel dossier nous sommes

os.getcwd()
# Out:
# '/Users/adrien/Documents/Documents/UniGE/cours/cours_images_2024'

# %%
# sortir d'un dossier

path = ".."

# %%
# fichiers et dossiers au bout du chemin

os.listdir(path)
# Out:
# ['textes_mondialisationCinema_Tournes',
#  'cours_images2',
#  'flights',
#  '.DS_Store',
#  'maskRCNN.zip',
#  'Untitled.ipynb',
#  'mondialisationHEAD',
#  'cours_Nicola_2023.ipynb',
#  'textes_mondialisation',
#  "Le cinéma américain- construction et internationalisation d'une industrie culturelle.txt",
#  'output',
#  'code',
#  'template_CR.txt',
#  'presentation_cours',
#  'maskRCNN',
#  'unige.jpg',
#  'textes_mondialisation.zip',
#  'mondialisation_culturelle_prisme_numerique',
#  'pdf_cours',
#  'icons',
#  'PDEN',
#  'Fondamentaux',
#  '.ipynb_checkpoints',
#  'IntroductionEtudesVisuelles.md',
#  'cours_images_2022',
#  'pres_DH_Day.txt',
#  'cours_images_2024',
#  'data',
#  'histoire_de_la_mondialisation_Tournes',
#  'cours_images']

# %%
# Cibler un dossier

path = "images"

# %%
# fichiers et dossiers au bout du chemin

os.listdir(path)
# Out:
# ['life.jpeg', 'japanPoster.jpg']

# %%
# nombre de fichiers et dossiers au bout du chemin

len(os.listdir(path))
# Out:
# 2

# %% [markdown]
# ### Une fonction pour importer un dossier
#
# Pour importer des images et les stocker il faut principalement:
# * scanner un dossier à l'aide d'une boucle
# * lire les images une à une
# * une liste vide pour stocker les images

# %%
# Créer une boucle

dossier = os.listdir(path)
for files in dossier:
    print(files)
# Out:
# life.jpeg
# japanPoster.jpg

# %%
# Pour lire les images

import cv2

# %%
# Lire les images

dossier = os.listdir(path)
for files in dossier:
    image_dossier = os.path.join(path, files) # on joint notre fichier à notre chemin
    image = cv2.imread(image_dossier) # on utilise la fonction pour lire les images
    print(image)
# Out:
# [[[165 165 165]
#   [156 156 156]
#   [154 154 154]
#   ...
#   [ 98  98  98]
#   [108 108 108]
#   [118 118 118]]
#
#  [[152 152 152]
#   [149 149 149]
#   [149 149 149]
#   ...
#   [ 98  98  98]
#   [109 109 109]
#   [120 120 120]]
#
#  [[137 137 137]
#   [139 139 139]
#   [138 138 138]
#   ...
#   [ 99  99  99]
#   [111 111 111]
#   [124 124 124]]
#
#  ...
#
#  [[198 198 198]
#   [189 189 189]
#   [177 177 177]
#   ...
#   [173 173 173]
#   [178 178 178]
#   [197 197 197]]
#
#  [[210 210 210]
#   [201 201 201]
#   [189 189 189]
#   ...
#   [191 191 191]
#   [192 192 192]
#   [208 208 208]]
#
#  [[221 221 221]
#   [212 212 212]
#   [200 200 200]
#   ...
#   [199 199 199]
#   [195 195 195]
#   [208 208 208]]]
# [[[ 76  73  75]
#   [ 82  79  81]
#   [ 82  75  78]
#   ...
#   [ 78  94 131]
#   [ 40  58  95]
#   [ 52  70 107]]
#
#  [[ 86  83  85]
#   [ 92  87  89]
#   [ 89  82  85]
#   ...
#   [ 91 109 146]
#   [ 64  82 119]
#   [ 51  69 106]]
#
#  [[ 83  78  79]
#   [ 83  78  79]
#   [ 78  71  74]
#   ...
#   [ 97 115 152]
#   [ 91 109 146]
#   [ 52  71 108]]
#
#  ...
#
#  [[ 74  75  89]
#   [ 71  72  86]
#   [ 70  71  85]
#   ...
#   [ 42  44  55]
#   [ 42  43  57]
#   [ 39  40  54]]
#
#  [[ 78  79  93]
#   [ 68  70  81]
#   [ 61  62  76]
#   ...
#   [ 30  32  43]
#   [ 34  35  49]
#   [ 34  35  49]]
#
#  [[141 143 154]
#   [132 134 144]
#   [125 127 138]
#   ...
#   [ 70  74  85]
#   [ 71  75  86]
#   [ 72  76  87]]]

# %%
# Lire et enregistrer les images

liste_images = [] # on crée une liste pour y enregister nos images
dossier = os.listdir(path)
for files in dossier:
    image_dossier = os.path.join(path, files)
    image = cv2.imread(image_dossier)
    liste_images.append(image) # après avoir lu nos images, on les enregistre
        
print("Nombre d'images : ", len(liste_images))
# Out:
# Nombre d'images :  2

# %%
# Créons une fonction simple pour importer les images d'un dossier

def importer_images(path):
    
    liste_images = []
    dossier = os.listdir(path)
    for files in dossier:
        image_dossier = os.path.join(path, files)
        image = cv2.imread(image_dossier)
        liste_images.append(image)
    return liste_images

# %%
# Utilisons la fonction

mes_images = importer_images(path="images")

# %%
len(mes_images)
# Out:
# 2

# %% [markdown]
# **La fonction est simple mais pas assez robuste. Il nous faut être sûr que ce sont des images que nous importons.**

# %% [markdown]
# ### Une fonction pour importer seulement des images
#
# Pour importer uniquement les images d'un dossier, il faut ajouter des conditions à notre fonction

# %%
# Créer une boucle avec une condition

dossier = os.listdir(path)
for files in dossier:
    if files.endswith('.jpeg'):
        print(files)
# Out:
# life.jpeg

# %%
# Créer une boucle avec plusieurs conditions

ext = [".jpeg", ".png", ".jpg"] # choisir les extensions qui définissent nos images
dossier = os.listdir(path)
for files in dossier:
    if files.endswith(tuple(ext)): # ici le code change un peu pour intégrer les extensions
        print(files)
# Out:
# life.jpeg
# japanPoster.jpg

# %% [markdown]
# **Profitons-en pour changer l'ordre des canaux de couleurs**

# %%
def importer_images(path):
    
    liste_images = []
    ext = [".jpeg", ".png", ".jpg"]
    dossier = os.listdir(path)
    for files in dossier:
        if files.endswith(tuple(ext)):
            image_dossier = os.path.join(path, files)
            image = cv2.imread(image_dossier)
            image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
            liste_images.append(image)
    return liste_images

# %%
# Utilisons la fonction

mes_images = importer_images(path=path)

# %%
len(mes_images)
# Out:
# 2

# %% [markdown]
# ## 2. Extraire des informations
#
# Lorsqu'on importe un dossier avec des images, il peut être utile d'en extraire les informations. Ces informations nous permettent de décrire nos données tout en rendant notre fonction plus robuste.
#
# ### Rappel sur les informations
#
# Les informations sont d'une part extraites et d'autres part stockées.

# %% [markdown]
# #### Rappel sur les dictionnaires

# %%
# Rappel sur les dictionnaires

# un dictionnaire se définit par des {}
# la clé se définit sur la gauche, entre " "
# entre la clé et la valeur, il y a :
# la valeur se définit sur la droit, selon le type (str, int, float, ...)
# entre chaque ligne, il y a une ,

eleve = { 
    "nom" : "Adrien", 
    "prenom" : "Jeanrenaud"
}

# %%
# L'objet

print(eleve)
# Out:
# {'nom': 'Adrien', 'prenom': 'Jeanrenaud'}

# %%
# Pour accéder aux éléments, par les clés

print(eleve["nom"])
# Out:
# Adrien

# %%
# passer d'un dictionnaire à un tableur

import pandas as pd

# %%
df = pd.DataFrame.from_dict(eleve, orient ='index')
df
# Out:
#                  0
# nom         Adrien
# prenom  Jeanrenaud

# %% [markdown]
# #### Rappel sur les informations de bases de l'image

# %%
# commencer par choisir une image

image = mes_images[0]

# %%
# visualiser

import matplotlib.pyplot as plt

plt.imshow(image)
plt.show()

# %%
# Est-ce une image ?

type(image)
# Out:
# numpy.ndarray

# %%
# Quelles dimensions

image.shape
# Out:
# (843, 1280, 3)

# %%
# Quelle taille

image.size
# Out:
# 3237120

# %% [markdown]
# **On peut également retirer les informations à partir du chemin**

# %%
# A partir d'un chemin

path = "affiches"

# %%
# Le nom de l'image est une information importante

files = os.listdir(path)
files[:10]
# Out:
# ['.DS_Store',
#  'LaStrada_Tchequie_1954.jpeg',
#  'test.tropy',
#  'Chinatown_USA_1974.jpg',
#  'phantomOfTheOpera_Sweden_1974.jpg',
#  'sosMiamiAirport_USA_1978.jpg',
#  'phantomOfTheOpera_Japan_1974.jpg',
#  'Chinatown_Japan_1974.jpg',
#  'apocalypseNow_Poland_1981.jpg']

# %%
# os.path.splitext, pour diviser le chemin 
# d'un côté le chemin (le nom)
# de l'autre l'extension

os.path.splitext(files[1])
# Out:
# ('LaStrada_Tchequie_1954', '.jpeg')

# %%
# Récupérer les informations

file, ext = os.path.splitext(files[1])

# %%
ext
# Out:
# '.jpeg'

# %%
file
# Out:
# 'LaStrada_Tchequie_1954'

# %%
# Dans le titre, il y a également des informations

file_info = file.split("_") # choisir le caractère pour diviser
file_info
# Out:
# ['LaStrada', 'Tchequie', '1954']

# %% [markdown]
# ### Extraires des informations en boucle
#
# Nous pouvons reprendre la fonction précédente et ajouter du code pour extraire et enregistrer les informations

# %%
# Où récupérer les informations ?

ext = [".jpeg", ".png", ".jpg"] # choisir les extensions qui définissent nos images
dossier = os.listdir(path)
for files in dossier[:5]:
    if files.endswith(tuple(ext)):
        image_dossier = os.path.join(path, files)
        file, ext = os.path.splitext(files)
        image = cv2.imread(image_dossier)
        print(image.shape, file, ext)
# Out:
# (2546, 1830, 3) LaStrada_Tchequie_1954 .jpeg
# (2090, 1448, 3) Chinatown_USA_1974 .jpg
# (1383, 960, 3) phantomOfTheOpera_Sweden_1974 .jpg

# %%
# Tout enregistrer dans un dictionnaire

liste_dic = [] # comme lorsque nous voulions enregistrer nos images, il faut une liste pour enregistrer le dictionnaire 
ext = [".jpeg", ".png", ".jpg"] # choisir les extensions qui définissent nos images
dossier = os.listdir(path)
for files in dossier[:5]:
    if files.endswith(tuple(ext)):
        image_dossier = os.path.join(path, files)
        file, ext = os.path.splitext(files)
        image = cv2.imread(image_dossier)
        dic = {
            "nom": file,
            "ext": ext,
            "hauteur": image.shape[0],
            "largeur": image.shape[1],
            "canaux": image.shape[2],
            "taille": image.size
        }
        liste_dic.append(dic)
print(liste_dic)
# Out:
# [{'nom': 'LaStrada_Tchequie_1954', 'ext': '.jpeg', 'hauteur': 2546, 'largeur': 1830, 'canaux': 3, 'taille': 13977540}, {'nom': 'Chinatown_USA_1974', 'ext': '.jpg', 'hauteur': 2090, 'largeur': 1448, 'canaux': 3, 'taille': 9078960}, {'nom': 'phantomOfTheOpera_Sweden_1974', 'ext': '.jpg', 'hauteur': 1383, 'largeur': 960, 'canaux': 3, 'taille': 3983040}]

# %%
# passer à un tableur

df = pd.DataFrame.from_dict(liste_dic)
df
# Out:
#                              nom    ext  hauteur  largeur  canaux    taille
# 0         LaStrada_Tchequie_1954  .jpeg     2546     1830       3  13977540
# 1             Chinatown_USA_1974   .jpg     2090     1448       3   9078960
# 2  phantomOfTheOpera_Sweden_1974   .jpg     1383      960       3   3983040

# %%
# extraire encore des informations

new_columns = df['nom'].str.split('_', expand=True)
df[['titre','pays', 'date']] = new_columns
df
# Out:
#                              nom    ext  hauteur  largeur  canaux    taille  \
# 0         LaStrada_Tchequie_1954  .jpeg     2546     1830       3  13977540
# 1             Chinatown_USA_1974   .jpg     2090     1448       3   9078960
# 2  phantomOfTheOpera_Sweden_1974   .jpg     1383      960       3   3983040
#
#                titre      pays  date
# 0           LaStrada  Tchequie  1954
# 1          Chinatown       USA  1974
# 2  phantomOfTheOpera    Sweden  1974

# %% [markdown]
# ### Visualiser les informations
#
# A partir du tableur, visualiser les informations permet de dégager des tendances et comprendre le type de données à partir desquelles nous travaillons

# %%
# Quelques infos sur son tableur

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 9 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   nom      3 non-null      object
#  1   ext      3 non-null      object
#  2   hauteur  3 non-null      int64
#  3   largeur  3 non-null      int64
#  4   canaux   3 non-null      int64
#  5   taille   3 non-null      int64
#  6   titre    3 non-null      object
#  7   pays     3 non-null      object
#  8   date     3 non-null      object
# dtypes: int64(4), object(5)
# memory usage: 344.0+ bytes

# %%
df.describe()
# Out:
#            hauteur      largeur  canaux        taille
# count     3.000000     3.000000     3.0  3.000000e+00
# mean   2006.333333  1412.666667     3.0  9.013180e+06
# std     585.996871   436.074917     0.0  4.997575e+06
# min    1383.000000   960.000000     3.0  3.983040e+06
# 25%    1736.500000  1204.000000     3.0  6.531000e+06
# 50%    2090.000000  1448.000000     3.0  9.078960e+06
# 75%    2318.000000  1639.000000     3.0  1.152825e+07
# max    2546.000000  1830.000000     3.0  1.397754e+07

# %%
# Accéder aux informations

print(f"Hauteur min. = {df.describe().iloc[3].hauteur} \nLargeur min. = {df.describe().iloc[3].largeur}")
# Out:
# Hauteur min. = 1383.0
# Largeur min. = 960.0

# %%
# Sur les couleurs et les valeurs de gris 

canaux = df.canaux.value_counts()
print(canaux)
# Out:
# canaux
# 3    3
# Name: count, dtype: int64

# %%
# avec un graphique

canaux.plot(kind='bar')
# Out:
# <Axes: xlabel='canaux'>

# %%
df.taille.value_counts().plot(kind='bar')
plt.xticks(rotation =45)
# Out:
# (array([0, 1, 2]),
#  [Text(0, 0, '13977540'), Text(1, 0, '9078960'), Text(2, 0, '3983040')])

# %%
# ajouter des informations sur le graphique

plt.figure(figsize=(14, 8))
df.ext.value_counts().plot(kind='bar', color="blue")
plt.xticks(rotation =45)
plt.title("Extensions des images")
plt.xlabel('Extensions')
plt.ylabel('Compte')
plt.show()

# %%
# enregistrer le graphique

plt.figure(figsize=(14, 8))
df.ext.value_counts().plot(kind='bar', color="blue")
plt.xticks(rotation =45)
plt.title("Extensions des images")
plt.xlabel('Extensions')
plt.ylabel('Compte')
plt.savefig("extensions.png", dpi=200)

# %%
new_rc_params = {'text.usetex': False,
"svg.fonttype": 'none'
}
plt.rcParams.update(new_rc_params)

# %%
# enregistrer le graphique en SVG

plt.figure(figsize=(14, 8))
df.ext.value_counts().plot(kind='bar', color="blue")
plt.xticks(rotation =45)
plt.title("Extensions des images")
plt.xlabel('Extensions')
plt.ylabel('Compte')
plt.savefig("extensions.svg")

# %% [markdown]
# **Lorsque le graphique est en SVG, vous pouvez le retoucher en dehors de votre code à l'aide d'un logiciel de traitement graphique. De plus, l'image a une meilleur définition.**

# %% [markdown]
# ## 3. Travailler avec des données textuelles et visuelles
#
# Les données textuelles sont importantes dans le traitement numérique des images. Ces données permettent de décrire l'image tout en la manipulant sur notre machine. D'une certaine manière, les données textuelles sont un préalable et un complément à la vision par ordinateur.
#
# Nous allons voir comment, à partir d'un tableur nous pouvons travailler avec des images

# %% [markdown]
# ### Importer et visualiser un tableau de données
#
# Nous venons de le faire précédemment: visualiser et comprendre les données d'un tableur. Désormais, nous le feront à partir d'un tableur de données "inconnues".
#
# * importer le fichier
# * informations sur les données
# * subdiviser les données selon nos intérêts

# %%
df = pd.read_csv('explore.csv')

# %%
df.head()
# Out:
#    numero_cluster                                       manifest_url  \
# 0              71  https://digi.ub.uni-heidelberg.de/diglit/iiif/...
# 1              71  https://gallica.bnf.fr/iiif/ark:/12148/bpt6k42...
# 2              71  https://gallica.bnf.fr/iiif/ark:/12148/bpt6k42...
# 3              71  https://iiif.archivelab.org/iiif/sim_computerw...
# 4              86  https://digi.ub.uni-heidelberg.de/diglit/iiif/...
#
#    canvas_number                                          image_url  \
# 0          122.0  https://digi.ub.uni-heidelberg.de/iiif/2/samle...
# 1          145.0  https://gallica.bnf.fr/iiif/ark:/12148/bpt6k42...
# 2          202.0  https://gallica.bnf.fr/iiif/ark:/12148/bpt6k42...
# 3          114.0  https://iiif.archivelab.org/iiif/sim_computerw...
# 4          672.0  https://digi.ub.uni-heidelberg.de/iiif/2/cicer...
#
#          City                   Country                    Title  \
# 0  Copenhagen                   Denmark                 Samleren
# 1       Paris                    France  L'Amour de l'art (1920)
# 2       Paris                    France    Cahiers d'art (Paris)
# 3  Framingham  United States of America            Computerworld
# 4     Leipzig                   Germany             Der Cicerone
#
#                                        wkt        Date         Journal Type  \
# 0   POINT(12.568888888889 55.676111111111)  1929-01-01          Art History
# 1   POINT(2.3513888888889 48.856944444444)  1937-01-01   Modern Art Journal
# 2   POINT(2.3513888888889 48.856944444444)  1947-01-01  Avant-garde Journal
# 3  POINT(-71.416666666667 42.279166666667)  2000-10-16            Computing
# 4                      POINT(12.375 51.34)  1922-01-01   Modern Art Journal
#
#    notice                 group_name    group_tags
# 0     NaN  VanGogh_Autoportrait_1889  autoportrait
# 1     NaN  VanGogh_Autoportrait_1889  autoportrait
# 2     NaN  VanGogh_Autoportrait_1889  autoportrait
# 3     NaN  VanGogh_Autoportrait_1889  autoportrait
# 4     NaN    VanGogh_CafeDeNuit_1888   scene_genre

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 147 entries, 0 to 146
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   numero_cluster  147 non-null    int64
#  1   manifest_url    147 non-null    object
#  2   canvas_number   142 non-null    float64
#  3   image_url       147 non-null    object
#  4   City            147 non-null    object
#  5   Country         147 non-null    object
#  6   Title           147 non-null    object
#  7   wkt             147 non-null    object
#  8   Date            147 non-null    object
#  9   Journal Type    147 non-null    object
#  10  notice          0 non-null      float64
#  11  group_name      147 non-null    object
#  12  group_tags      147 non-null    object
# dtypes: float64(2), int64(1), object(10)
# memory usage: 15.1+ KB

# %%
# quelles dates

df.Date.value_counts()
# Out:
# Date
# 1947-01-01    24
# 1937-01-01    21
# 1926-01-01    12
# 1928-01-01     9
# 1922-01-01     8
# 1929-01-01     8
# 1927-01-01     7
# 1924-02-01     6
# 1930-01-01     6
# 1925-01-01     5
# 1921-01-01     5
# 1912-01-01     5
# 1932-01-01     3
# 1966-01-01     3
# 1938-01-01     2
# 1996-01-01     2
# 1914-10-08     1
# 1966-07-01     1
# 1943-07-01     1
# 1929-12-01     1
# 1934-01-01     1
# 1923-07-15     1
# 1920-12-15     1
# 1943-02-01     1
# 1913-06-01     1
# 1930-11-01     1
# 1983-01-01     1
# 1907-10-01     1
# 1911-01-01     1
# 1995-08-01     1
# 1930-12-01     1
# 1923-06-01     1
# 1936-07-01     1
# 1919-01-01     1
# 1920-05-15     1
# 2000-10-16     1
# 2002-05-01     1
# Name: count, dtype: int64

# %%
# quels tags

df.group_tags.value_counts()
# Out:
# group_tags
# Portrait             41
# Paysage              40
# autoportrait         21
# nature_morte         18
# scene_genre          15
# Religious subject     8
# portrait              3
# Rural scene           1
# Name: count, dtype: int64

# %%
df_portrait = df.loc[df['group_tags'] == "Portrait"]
df_portrait
# Out:
#      numero_cluster                                       manifest_url  \
# 29              258  https://gallica.bnf.fr/iiif/ark:/12148/bpt6k42...
# 45              135  https://digi.ub.uni-heidelberg.de/diglit/iiif/...
# 46              135  https://digi.ub.uni-heidelberg.de/diglit/iiif/...
# 47              135  https://digi.ub.uni-heidelberg.de/diglit/iiif/...
# 48              135  https://digi.ub.uni-heidelberg.de/diglit/iiif/...
# 49              135  https://digi.ub.uni-heidelberg.de/diglit/iiif/...
# 50              135  https://digi.ub.uni-heidelberg.de/diglit/iiif/...
# 51              135  https://gallica.bnf.fr/iiif/ark:/12148/bpt6k42...
# 52              135  https://gallica.bnf.fr/iiif/ark:/12148/bpt6k61...
# 53              135  https://gallica.bnf.fr/iiif/ark:/12148/bpt6k30...
# 54              135  https://gallica.bnf.fr/iiif/ark:/12148/bpt6k42...
# 55              135  https://iiif.archivelab.org/iiif/sim_arts-maga...
# 56              135  https://iiif.archivelab.org/iiif/sim_arts-maga...
# 57              135  https://iiif.archivelab.org/iiif/sim_arts-maga...
# 58              270  https://gallica.bnf.fr/iiif/ark:/12148/bpt6k42...
# 59              136  https://digi.ub.uni-heidelberg.de/diglit/iiif/...
# 60              136  https://digi.ub.uni-heidelberg.de/diglit/iiif/...
# 61              136  https://digi.ub.uni-heidelberg.de/diglit/iiif/...
# 62              136  https://gallica.bnf.fr/iiif/ark:/12148/bpt6k61...
# 63              136  https://gallica.bnf.fr/iiif/ark:/12148/bpt6k42...
# 64              136  https://gallica.bnf.fr/iiif/ark:/12148/bpt6k42...
# 93              282  https://iiif.unige.ch/dhportal/ug8025333/manifest
# 98              250  https://digi.ub.uni-heidelberg.de/diglit/iiif/...
# 109             262  https://gallica.bnf.fr/iiif/ark:/12148/bpt6k42...
# 110             265  https://digi.ub.uni-heidelberg.de/diglit/iiif/...
# 111             265  https://digi.ub.uni-heidelberg.de/diglit/iiif/...
# 112             265  https://gallica.bnf.fr/iiif/ark:/12148/bpt6k42...
# 113             265  https://gallica.bnf.fr/iiif/ark:/12148/bpt6k42...
# 114             265  https://gallica.bnf.fr/iiif/ark:/12148/bpt6k61...
# 115             268  https://gallica.bnf.fr/iiif/ark:/12148/bpt6k42...
# 120             289  https://gallica.bnf.fr/iiif/ark:/12148/bpt6k42...
# 121             289  https://gallica.bnf.fr/iiif/ark:/12148/bpt6k97...
# 131             266  https://digi.ub.uni-heidelberg.de/diglit/iiif/...
# 132             266  https://gallica.bnf.fr/iiif/ark:/12148/bpt6k42...
# 139             281  https://digi.ub.uni-heidelberg.de/diglit/iiif/...
# 140             281  https://digi.ub.uni-heidelberg.de/diglit/iiif/...
# 141             281  https://gallica.bnf.fr/iiif/ark:/12148/bpt6k42...
# 142             281  https://iiif.archivelab.org/iiif/sim_carnegie_...
# 144             287  https://digi.ub.uni-heidelberg.de/diglit/iiif/...
# 145             287  https://gallica.bnf.fr/iiif/ark:/12148/bpt6k30...
# 146             287  https://gallica.bnf.fr/iiif/ark:/12148/bpt6k97...
#
#      canvas_number                                          image_url  \
# 29           389.0  https://gallica.bnf.fr/iiif/ark:/12148/bpt6k42...
# 45           262.0  https://digi.ub.uni-heidelberg.de/iiif/2/rhs19...
# 46           305.0  https://digi.ub.uni-heidelberg.de/iiif/2/dkd19...
# 47           338.0  https://digi.ub.uni-heidelberg.de/iiif/2/dkd19...
# 48           501.0  https://digi.ub.uni-heidelberg.de/iiif/2/kunst...
# 49           578.0  https://digi.ub.uni-heidelberg.de/iiif/2/cicer...
# 50           647.0  https://digi.ub.uni-heidelberg.de/iiif/2/cicer...
# 51           143.0  https://gallica.bnf.fr/iiif/ark:/12148/bpt6k42...
# 52            20.0  https://gallica.bnf.fr/iiif/ark:/12148/bpt6k61...
# 53           216.0  https://gallica.bnf.fr/iiif/ark:/12148/bpt6k30...
# 54           247.0  https://gallica.bnf.fr/iiif/ark:/12148/bpt6k42...
# 55             NaN  https://iiif.archivelab.org/iiif/sim_arts-maga...
# 56             NaN  https://iiif.archivelab.org/iiif/sim_arts-maga...
# 57             NaN  https://iiif.archivelab.org/iiif/sim_arts-maga...
# 58           186.0  https://gallica.bnf.fr/iiif/ark:/12148/bpt6k42...
# 59            58.0  https://digi.ub.uni-heidelberg.de/iiif/2/dkd19...
# 60           357.0  https://digi.ub.uni-heidelberg.de/iiif/2/kunst...
# 61           804.0  https://digi.ub.uni-heidelberg.de/iiif/2/cicer...
# 62           131.0  https://gallica.bnf.fr/iiif/ark:/12148/bpt6k61...
# 63           147.0  https://gallica.bnf.fr/iiif/ark:/12148/bpt6k42...
# 64           332.0  https://gallica.bnf.fr/iiif/ark:/12148/bpt6k42...
# 93             0.0  https://iiif.unige.ch/iiif/2/fedora_ug8073947;...
# 98           122.0  https://digi.ub.uni-heidelberg.de/iiif/2/cicer...
# 109          226.0  https://gallica.bnf.fr/iiif/ark:/12148/bpt6k42...
# 110          104.0  https://digi.ub.uni-heidelberg.de/iiif/2/cicer...
# 111          147.0  https://digi.ub.uni-heidelberg.de/iiif/2/samle...
# 112          140.0  https://gallica.bnf.fr/iiif/ark:/12148/bpt6k42...
# 113          224.0  https://gallica.bnf.fr/iiif/ark:/12148/bpt6k42...
# 114            6.0  https://gallica.bnf.fr/iiif/ark:/12148/bpt6k61...
# 115          240.0  https://gallica.bnf.fr/iiif/ark:/12148/bpt6k42...
# 120          276.0  https://gallica.bnf.fr/iiif/ark:/12148/bpt6k42...
# 121          356.0  https://gallica.bnf.fr/iiif/ark:/12148/bpt6k97...
# 131          265.0  https://digi.ub.uni-heidelberg.de/iiif/2/jugen...
# 132          250.0  https://gallica.bnf.fr/iiif/ark:/12148/bpt6k42...
# 139          261.0  https://digi.ub.uni-heidelberg.de/iiif/2/rhs19...
# 140          335.0  https://digi.ub.uni-heidelberg.de/iiif/2/dkd19...
# 141          164.0  https://gallica.bnf.fr/iiif/ark:/12148/bpt6k42...
# 142           17.0  https://iiif.archivelab.org/iiif/sim_carnegie_...
# 144          532.0  https://digi.ub.uni-heidelberg.de/iiif/2/cicer...
# 145          271.0  https://gallica.bnf.fr/iiif/ark:/12148/bpt6k30...
# 146           61.0  https://gallica.bnf.fr/iiif/ark:/12148/bpt6k97...
#
#               City                   Country  \
# 29           Paris                    France
# 45          Warsaw                    Poland
# 46       Stuttgart                   Germany
# 47       Stuttgart                   Germany
# 48          Berlin                   Germany
# 49         Leipzig                   Germany
# 50         Leipzig                   Germany
# 51           Paris                    France
# 52           Paris                    France
# 53           Paris                    France
# 54           Paris                    France
# 55   New York City  United States of America
# 56   New York City  United States of America
# 57   New York City  United States of America
# 58           Paris                    France
# 59       Stuttgart                   Germany
# 60          Berlin                   Germany
# 61         Leipzig                   Germany
# 62           Paris                    France
# 63           Paris                    France
# 64           Paris                    France
# 93       Barcelona                     Spain
# 98         Leipzig                   Germany
# 109          Paris                    France
# 110        Leipzig                   Germany
# 111     Copenhagen                   Denmark
# 112          Paris                    France
# 113          Paris                    France
# 114          Paris                    France
# 115          Paris                    France
# 120          Paris                    France
# 121          Paris                    France
# 131         Munich                   Germany
# 132          Paris                    France
# 139         Warsaw                    Poland
# 140      Stuttgart                   Germany
# 141          Paris                    France
# 142     Pittsburgh  United States of America
# 144        Leipzig                   Germany
# 145          Paris                    France
# 146          Paris                    France
#
#                                     Title  \
# 29                L'Amour de l'art (1920)
# 45                Rocznik Historii Sztuki
# 46          Deutsche Kunst und Dekoration
# 47          Deutsche Kunst und Dekoration
# 48                      Der Kunstwanderer
# 49                           Der Cicerone
# 50                           Der Cicerone
# 51                L'Amour de l'art (1920)
# 52                                 Formes
# 53             L'Art vivant (Paris. 1925)
# 54                  Cahiers d'art (Paris)
# 55                          Arts Magazine
# 56                          Arts Magazine
# 57                          Arts Magazine
# 58                  Cahiers d'art (Paris)
# 59          Deutsche Kunst und Dekoration
# 60                      Der Kunstwanderer
# 61                           Der Cicerone
# 62   Gazette des beaux-arts (Paris. 1859)
# 63                L'Amour de l'art (1920)
# 64                L'Amour de l'art (1920)
# 93                           Revista Nova
# 98                           Der Cicerone
# 109                 Cahiers d'art (Paris)
# 110                          Der Cicerone
# 111                              Samleren
# 112               L'Amour de l'art (1920)
# 113                 Cahiers d'art (Paris)
# 114      Le Bulletin de la vie artistique
# 115                 Cahiers d'art (Paris)
# 120                 Cahiers d'art (Paris)
# 121                 Cahiers d'art (Paris)
# 131                                Jugend
# 132                 Cahiers d'art (Paris)
# 139               Rocznik Historii Sztuki
# 140         Deutsche Kunst und Dekoration
# 141               L'Amour de l'art (1920)
# 142                              Carnegie
# 144                          Der Cicerone
# 145            L'Art vivant (Paris. 1925)
# 146                 Cahiers d'art (Paris)
#
#                                         wkt        Date         Journal Type  \
# 29   POINT(2.3513888888889 48.856944444444)  1924-02-01   Modern Art Journal
# 45          POINT(21.011111111111113 52.23)  1966-01-01          Art History
# 46            POINT(9.1775 48.776111111111)  1912-01-01       Decorative Art
# 47            POINT(9.1775 48.776111111111)  1921-01-01       Decorative Art
# 48   POINT(13.383333333333 52.516666666667)  1927-01-01          Art Journal
# 49                      POINT(12.375 51.34)  1912-01-01   Modern Art Journal
# 50                      POINT(12.375 51.34)  1922-01-01   Modern Art Journal
# 51   POINT(2.3513888888889 48.856944444444)  1937-01-01   Modern Art Journal
# 52   POINT(2.3513888888889 48.856944444444)  1932-01-01   Modern Art Journal
# 53   POINT(2.3513888888889 48.856944444444)  1937-01-01   Modern Art Journal
# 54   POINT(2.3513888888889 48.856944444444)  1947-01-01  Avant-garde Journal
# 55              POINT(-74.006015 40.712728)  1926-01-01          Art Journal
# 56              POINT(-74.006015 40.712728)  1926-01-01          Art Journal
# 57              POINT(-74.006015 40.712728)  1926-01-01          Art Journal
# 58   POINT(2.3513888888889 48.856944444444)  1947-01-01  Avant-garde Journal
# 59            POINT(9.1775 48.776111111111)  1921-01-01       Decorative Art
# 60   POINT(13.383333333333 52.516666666667)  1930-01-01          Art Journal
# 61                      POINT(12.375 51.34)  1912-01-01   Modern Art Journal
# 62   POINT(2.3513888888889 48.856944444444)  1928-01-01          Art Journal
# 63   POINT(2.3513888888889 48.856944444444)  1937-01-01   Modern Art Journal
# 64   POINT(2.3513888888889 48.856944444444)  1926-01-01   Modern Art Journal
# 93           POINT(2.1769444444444 41.3825)  1914-10-08               Humour
# 98                      POINT(12.375 51.34)  1927-01-01   Modern Art Journal
# 109  POINT(2.3513888888889 48.856944444444)  1947-01-01  Avant-garde Journal
# 110                     POINT(12.375 51.34)  1928-01-01   Modern Art Journal
# 111  POINT(12.568888888889 55.676111111111)  1928-01-01          Art History
# 112  POINT(2.3513888888889 48.856944444444)  1937-01-01   Modern Art Journal
# 113  POINT(2.3513888888889 48.856944444444)  1947-01-01  Avant-garde Journal
# 114  POINT(2.3513888888889 48.856944444444)  1923-07-15   Modern Art Journal
# 115  POINT(2.3513888888889 48.856944444444)  1947-01-01  Avant-garde Journal
# 120  POINT(2.3513888888889 48.856944444444)  1947-01-01  Avant-garde Journal
# 121  POINT(2.3513888888889 48.856944444444)  1927-01-01  Avant-garde Journal
# 131                   POINT(11.575 48.1375)  1929-01-01   Modern Art Journal
# 132  POINT(2.3513888888889 48.856944444444)  1947-01-01  Avant-garde Journal
# 139         POINT(21.011111111111113 52.23)  1966-01-01          Art History
# 140           POINT(9.1775 48.776111111111)  1921-01-01       Decorative Art
# 141  POINT(2.3513888888889 48.856944444444)  1937-01-01   Modern Art Journal
# 142            POINT(-80 40.44166666666667)  1943-02-01         Philanthropy
# 144                     POINT(12.375 51.34)  1926-01-01   Modern Art Journal
# 145  POINT(2.3513888888889 48.856944444444)  1938-01-01   Modern Art Journal
# 146  POINT(2.3513888888889 48.856944444444)  1932-01-01  Avant-garde Journal
#
#      notice                                         group_name group_tags
# 29      NaN                          VanGogh_ItalianWoman_1887   Portrait
# 45      NaN                            VanGogh_Arlesienne_1888   Portrait
# 46      NaN                            VanGogh_Arlesienne_1888   Portrait
# 47      NaN                            VanGogh_Arlesienne_1888   Portrait
# 48      NaN                            VanGogh_Arlesienne_1888   Portrait
# 49      NaN                            VanGogh_Arlesienne_1888   Portrait
# 50      NaN                            VanGogh_Arlesienne_1888   Portrait
# 51      NaN                            VanGogh_Arlesienne_1888   Portrait
# 52      NaN                            VanGogh_Arlesienne_1888   Portrait
# 53      NaN                            VanGogh_Arlesienne_1888   Portrait
# 54      NaN                            VanGogh_Arlesienne_1888   Portrait
# 55      NaN                            VanGogh_Arlesienne_1888   Portrait
# 56      NaN                            VanGogh_Arlesienne_1888   Portrait
# 57      NaN                            VanGogh_Arlesienne_1888   Portrait
# 58      NaN              VanGogh_PortraitArtisteSansBarbe_1889   Portrait
# 59      NaN                              VanGogh_DrGachet_1890   Portrait
# 60      NaN                              VanGogh_DrGachet_1890   Portrait
# 61      NaN                              VanGogh_DrGachet_1890   Portrait
# 62      NaN                              VanGogh_DrGachet_1890   Portrait
# 63      NaN                              VanGogh_DrGachet_1890   Portrait
# 64      NaN                              VanGogh_DrGachet_1890   Portrait
# 93      NaN                 VanGogh_PortraitAdelineRavoux_1890   Portrait
# 98      NaN             VanGogh_HeadofPeasantWomanWithCap_1884   Portrait
# 109     NaN               VanGogh_WomanInTheCafeTambourin_1887   Portrait
# 110     NaN                     VanGogh_PortaitPereTanguy_1888   Portrait
# 111     NaN                     VanGogh_PortaitPereTanguy_1888   Portrait
# 112     NaN                     VanGogh_PortaitPereTanguy_1888   Portrait
# 113     NaN                     VanGogh_PortaitPereTanguy_1888   Portrait
# 114     NaN                     VanGogh_PortaitPereTanguy_1888   Portrait
# 115     NaN                                VanGogh_Zouave_1888   Portrait
# 120     NaN                VanGogh_YoungManWithCornflower_1890   Portrait
# 121     NaN                VanGogh_YoungManWithCornflower_1890   Portrait
# 131     NaN                 VanGogh_PorrtaitCamilleRoulin_1888   Portrait
# 132     NaN                 VanGogh_PorrtaitCamilleRoulin_1888   Portrait
# 139     NaN        VanGogh_ArlesiennePortraitMadameGinoux_1890   Portrait
# 140     NaN        VanGogh_ArlesiennePortraitMadameGinoux_1890   Portrait
# 141     NaN        VanGogh_ArlesiennePortraitMadameGinoux_1890   Portrait
# 142     NaN        VanGogh_ArlesiennePortraitMadameGinoux_1890   Portrait
# 144     NaN  VanGogh_YoungPEasantGirlInAStraxHatSittingInFr...   Portrait
# 145     NaN  VanGogh_YoungPEasantGirlInAStraxHatSittingInFr...   Portrait
# 146     NaN  VanGogh_YoungPEasantGirlInAStraxHatSittingInFr...   Portrait

# %% [markdown]
# ### Télécharger les données visuelles
#
# Nous avons un tableau de données avec un lien pour télécharger les images. Lors de cette phase, le plus important est:
#
# * créer un dossier pour récupérer nos images
# * créer des noms de fichier "robuste"
# * lier les données textuelles et visuelles

# %%
path_images = "VanGogh_portrait"
if not os.path.isdir(path_images):
        os.mkdir(path_images)

# %%
# vérifier le chemin au dossier

os.path.isdir(path_images)
# Out:
# True

# %%
# créer un hash pour éviter que deux images aient le même nom

df_portrait["Filename"] = pd.util.hash_pandas_object(df_portrait, index=False).astype(str)
# Out:
# /var/folders/9j/gtvq24nd2vx3p0mnny0l4vlr0000gq/T/ipykernel_44728/3695232088.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_portrait["Filename"] = pd.util.hash_pandas_object(df_portrait, index=False).astype(str)

# %%
df_portrait.head()
# Out:
#     numero_cluster                                       manifest_url  \
# 29             258  https://gallica.bnf.fr/iiif/ark:/12148/bpt6k42...
# 45             135  https://digi.ub.uni-heidelberg.de/diglit/iiif/...
# 46             135  https://digi.ub.uni-heidelberg.de/diglit/iiif/...
# 47             135  https://digi.ub.uni-heidelberg.de/diglit/iiif/...
# 48             135  https://digi.ub.uni-heidelberg.de/diglit/iiif/...
#
#     canvas_number                                          image_url  \
# 29          389.0  https://gallica.bnf.fr/iiif/ark:/12148/bpt6k42...
# 45          262.0  https://digi.ub.uni-heidelberg.de/iiif/2/rhs19...
# 46          305.0  https://digi.ub.uni-heidelberg.de/iiif/2/dkd19...
# 47          338.0  https://digi.ub.uni-heidelberg.de/iiif/2/dkd19...
# 48          501.0  https://digi.ub.uni-heidelberg.de/iiif/2/kunst...
#
#          City  Country                          Title  \
# 29      Paris   France        L'Amour de l'art (1920)
# 45     Warsaw   Poland        Rocznik Historii Sztuki
# 46  Stuttgart  Germany  Deutsche Kunst und Dekoration
# 47  Stuttgart  Germany  Deutsche Kunst und Dekoration
# 48     Berlin  Germany              Der Kunstwanderer
#
#                                        wkt        Date        Journal Type  \
# 29  POINT(2.3513888888889 48.856944444444)  1924-02-01  Modern Art Journal
# 45         POINT(21.011111111111113 52.23)  1966-01-01         Art History
# 46           POINT(9.1775 48.776111111111)  1912-01-01      Decorative Art
# 47           POINT(9.1775 48.776111111111)  1921-01-01      Decorative Art
# 48  POINT(13.383333333333 52.516666666667)  1927-01-01         Art Journal
#
#     notice                 group_name group_tags              Filename
# 29     NaN  VanGogh_ItalianWoman_1887   Portrait   8861007808267359747
# 45     NaN    VanGogh_Arlesienne_1888   Portrait   2727921280430073225
# 46     NaN    VanGogh_Arlesienne_1888   Portrait  12723693742842148905
# 47     NaN    VanGogh_Arlesienne_1888   Portrait   5605650274174973682
# 48     NaN    VanGogh_Arlesienne_1888   Portrait   8854971534209556026

# %%
# ajouter des informations dans le nom et une extension

df_portrait.Filename = df_portrait.Filename +"_"+ df_portrait.Date+ ".jpg"
# Out:
# /var/folders/9j/gtvq24nd2vx3p0mnny0l4vlr0000gq/T/ipykernel_44728/863531668.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_portrait.Filename = df_portrait.Filename +"_"+ df_portrait.Date+ ".jpg"

# %%
df_portrait.head()
# Out:
#     numero_cluster                                       manifest_url  \
# 29             258  https://gallica.bnf.fr/iiif/ark:/12148/bpt6k42...
# 45             135  https://digi.ub.uni-heidelberg.de/diglit/iiif/...
# 46             135  https://digi.ub.uni-heidelberg.de/diglit/iiif/...
# 47             135  https://digi.ub.uni-heidelberg.de/diglit/iiif/...
# 48             135  https://digi.ub.uni-heidelberg.de/diglit/iiif/...
#
#     canvas_number                                          image_url  \
# 29          389.0  https://gallica.bnf.fr/iiif/ark:/12148/bpt6k42...
# 45          262.0  https://digi.ub.uni-heidelberg.de/iiif/2/rhs19...
# 46          305.0  https://digi.ub.uni-heidelberg.de/iiif/2/dkd19...
# 47          338.0  https://digi.ub.uni-heidelberg.de/iiif/2/dkd19...
# 48          501.0  https://digi.ub.uni-heidelberg.de/iiif/2/kunst...
#
#          City  Country                          Title  \
# 29      Paris   France        L'Amour de l'art (1920)
# 45     Warsaw   Poland        Rocznik Historii Sztuki
# 46  Stuttgart  Germany  Deutsche Kunst und Dekoration
# 47  Stuttgart  Germany  Deutsche Kunst und Dekoration
# 48     Berlin  Germany              Der Kunstwanderer
#
#                                        wkt        Date        Journal Type  \
# 29  POINT(2.3513888888889 48.856944444444)  1924-02-01  Modern Art Journal
# 45         POINT(21.011111111111113 52.23)  1966-01-01         Art History
# 46           POINT(9.1775 48.776111111111)  1912-01-01      Decorative Art
# 47           POINT(9.1775 48.776111111111)  1921-01-01      Decorative Art
# 48  POINT(13.383333333333 52.516666666667)  1927-01-01         Art Journal
#
#     notice                 group_name group_tags  \
# 29     NaN  VanGogh_ItalianWoman_1887   Portrait
# 45     NaN    VanGogh_Arlesienne_1888   Portrait
# 46     NaN    VanGogh_Arlesienne_1888   Portrait
# 47     NaN    VanGogh_Arlesienne_1888   Portrait
# 48     NaN    VanGogh_Arlesienne_1888   Portrait
#
#                                Filename
# 29   8861007808267359747_1924-02-01.jpg
# 45   2727921280430073225_1966-01-01.jpg
# 46  12723693742842148905_1912-01-01.jpg
# 47   5605650274174973682_1921-01-01.jpg
# 48   8854971534209556026_1927-01-01.jpg

# %%
# créer un dicitonnaire avec le lien et le nom du fichier

id_dict = df_portrait[['image_url', 'Filename']].set_index('image_url')['Filename'].to_dict()

# %%
id_dict
# Out:
# {'https://gallica.bnf.fr/iiif/ark:/12148/bpt6k4226339k/f390/409,623,2778,3724/full/0/default.jpg': '8861007808267359747_1924-02-01.jpg',
#  'https://digi.ub.uni-heidelberg.de/iiif/2/rhs1966%3A257.jpg/301,165,1320,1542/full/0/default.jpg': '2727921280430073225_1966-01-01.jpg',
#  'https://digi.ub.uni-heidelberg.de/iiif/2/dkd1912%3A291.jpg/250,281,1574,1995/full/0/default.jpg': '12723693742842148905_1912-01-01.jpg',
#  'https://digi.ub.uni-heidelberg.de/iiif/2/dkd1921_1922%3A313.jpg/226,148,1572,1999/full/0/default.jpg': '5605650274174973682_1921-01-01.jpg',
#  'https://digi.ub.uni-heidelberg.de/iiif/2/kunstwanderer1927_1928%3A476.jpg/1101,1563,960,1178/full/0/default.jpg': '8854971534209556026_1927-01-01.jpg',
#  'https://digi.ub.uni-heidelberg.de/iiif/2/cicerone1912%3A547.jpg/873,1350,1054,1432/full/0/default.jpg': '8193669398584550900_1912-01-01.jpg',
#  'https://digi.ub.uni-heidelberg.de/iiif/2/cicerone1922%3A626.jpg/220,104,1251,985/full/0/default.jpg': '4341553720444709626_1922-01-01.jpg',
#  'https://gallica.bnf.fr/iiif/ark:/12148/bpt6k4226205f/f144/1792,464,1426,1924/full/0/default.jpg': '2166384085171623245_1937-01-01.jpg',
#  'https://gallica.bnf.fr/iiif/ark:/12148/bpt6k61498804/f21/192,217,1998,2472/full/0/default.jpg': '10534432595828564949_1932-01-01.jpg',
#  'https://gallica.bnf.fr/iiif/ark:/12148/bpt6k30563567/f217/899,282,2132,2693/full/0/default.jpg': '2221750040905946975_1937-01-01.jpg',
#  'https://gallica.bnf.fr/iiif/ark:/12148/bpt6k42260903/f248/597,444,3192,3762/full/0/default.jpg': '4203279557831407815_1947-01-01.jpg',
#  'https://iiif.archivelab.org/iiif/sim_arts-magazine_1940-06-01_14_17$5/1910,426,1062,1290/full/0/default.jpg': '16699326264690741888_1926-01-01.jpg',
#  'https://iiif.archivelab.org/iiif/sim_arts-magazine_1946-08-01_20_19$0/653,1419,2333,2408/full/0/default.jpg': '3985589603700027241_1926-01-01.jpg',
#  'https://iiif.archivelab.org/iiif/sim_arts-magazine_1951-11-15_26_4$18/1118,391,796,1004/full/0/default.jpg': '6016089789330544112_1926-01-01.jpg',
#  'https://gallica.bnf.fr/iiif/ark:/12148/bpt6k42260903/f187/922,2403,1588,1965/full/0/default.jpg': '17198757066664151924_1947-01-01.jpg',
#  'https://digi.ub.uni-heidelberg.de/iiif/2/dkd1921_1922%3A039.jpg/319,304,1569,1861/full/0/default.jpg': '1966546017689930770_1921-01-01.jpg',
#  'https://digi.ub.uni-heidelberg.de/iiif/2/kunstwanderer1930_1931%3A346.jpg/661,115,881,1042/full/0/default.jpg': '881873418366666785_1930-01-01.jpg',
#  'https://digi.ub.uni-heidelberg.de/iiif/2/cicerone1912%3A763.jpg/406,338,1299,1543/full/0/default.jpg': '12198474087498669377_1912-01-01.jpg',
#  'https://gallica.bnf.fr/iiif/ark:/12148/bpt6k61112882/f132/990,859,959,1159/full/0/default.jpg': '14270947076500235876_1928-01-01.jpg',
#  'https://gallica.bnf.fr/iiif/ark:/12148/bpt6k4226205f/f148/650,829,2693,3186/full/0/default.jpg': '15594523917536520026_1937-01-01.jpg',
#  'https://gallica.bnf.fr/iiif/ark:/12148/bpt6k4226258k/f333/1741,2625,1482,1749/full/0/default.jpg': '3455430818368260423_1926-01-01.jpg',
#  'https://iiif.unige.ch/iiif/2/fedora_ug8073947;1/70,300,1163,1364/full/0/default.jpg': '17002727225545309646_1914-10-08.jpg',
#  'https://digi.ub.uni-heidelberg.de/iiif/2/cicerone1927%3A00_101.jpg/172,1351,614,780/full/0/default.jpg': '12092641017301758010_1927-01-01.jpg',
#  'https://gallica.bnf.fr/iiif/ark:/12148/bpt6k42260903/f227/83,389,3362,3954/full/0/default.jpg': '16762741219501322896_1947-01-01.jpg',
#  'https://digi.ub.uni-heidelberg.de/iiif/2/cicerone1928%3A0_075.jpg/253,194,907,1171/full/0/default.jpg': '3781903444428630705_1928-01-01.jpg',
#  'https://digi.ub.uni-heidelberg.de/iiif/2/samleren1928%3A0_080_bf.jpg/721,587,1134,1498/full/0/default.jpg': '16586066764935691791_1928-01-01.jpg',
#  'https://gallica.bnf.fr/iiif/ark:/12148/bpt6k4226205f/f141/429,1744,1117,1430/full/0/default.jpg': '2122596887146135925_1937-01-01.jpg',
#  'https://gallica.bnf.fr/iiif/ark:/12148/bpt6k42260903/f225/375,487,2784,3636/full/0/default.jpg': '13274513606033906053_1947-01-01.jpg',
#  'https://gallica.bnf.fr/iiif/ark:/12148/bpt6k61265470/f7/804,1212,521,689/full/0/default.jpg': '14691511290093773310_1923-07-15.jpg',
#  'https://gallica.bnf.fr/iiif/ark:/12148/bpt6k42260903/f241/273,480,3028,3761/full/0/default.jpg': '169838889892014754_1947-01-01.jpg',
#  'https://gallica.bnf.fr/iiif/ark:/12148/bpt6k42260903/f277/349,511,2764,3616/full/0/default.jpg': '10557942634866141177_1947-01-01.jpg',
#  'https://gallica.bnf.fr/iiif/ark:/12148/bpt6k97952378/f357/237,573,2789,3640/full/0/default.jpg': '8177834103126173014_1927-01-01.jpg',
#  'https://digi.ub.uni-heidelberg.de/iiif/2/jugend1929%3A265.jpg/342,556,2410,3027/full/0/default.jpg': '15220243292037390101_1929-01-01.jpg',
#  'https://gallica.bnf.fr/iiif/ark:/12148/bpt6k42260903/f251/118,537,3147,3534/full/0/default.jpg': '17898751244050429049_1947-01-01.jpg',
#  'https://digi.ub.uni-heidelberg.de/iiif/2/rhs1966%3A256.jpg/1058,190,830,1008/full/0/default.jpg': '13104323162462611673_1966-01-01.jpg',
#  'https://digi.ub.uni-heidelberg.de/iiif/2/dkd1921_1922%3A310.jpg/268,277,1616,1922/full/0/default.jpg': '6950481323937729753_1921-01-01.jpg',
#  'https://gallica.bnf.fr/iiif/ark:/12148/bpt6k4226205f/f165/410,596,972,1197/full/0/default.jpg': '910170732834132017_1937-01-01.jpg',
#  'https://iiif.archivelab.org/iiif/sim_carnegie_1943-02_16_9$17/844,1972,789,951/full/0/default.jpg': '14042283349472807806_1943-02-01.jpg',
#  'https://digi.ub.uni-heidelberg.de/iiif/2/cicerone1926%3A0_513.jpg/104,170,1229,982/full/0/default.jpg': '5920090843904859827_1926-01-01.jpg',
#  'https://gallica.bnf.fr/iiif/ark:/12148/bpt6k3060547c/f272/1791,2422,1573,2008/full/0/default.jpg': '14575878468824219134_1938-01-01.jpg',
#  'https://gallica.bnf.fr/iiif/ark:/12148/bpt6k9796461x/f62/421,559,2941,3680/full/0/default.jpg': '17081519575713646347_1932-01-01.jpg'}

# %%
# on reprend le code du cours précédent

import requests
import time
from tqdm import tqdm

for media_url, identifier in tqdm(id_dict.items(), desc="Images_downloaded"):
    filename = os.path.join(path_images, identifier)
    try:
        img = requests.get(media_url, stream=True).content
        #time.sleep(1)
        with open(filename, 'wb') as handler:
            handler.write(img)
    except requests.RequestException as e:
        print(f"Error downloading image from {media_url}: {e}")
# Out:
# Images_downloaded: 100%|█████| 41/41 [01:21<00:00,  1.99s/it]

# %%
# combien d'images téléchargées ?

len(os.listdir("VanGogh_portrait"))
# Out:
# 41

# %%
# modifier le tableur selon les images téléchargées

l = (os.listdir("VanGogh_portrait"))
df_portrait_less = df_portrait[df_portrait['Filename'].isin(l)]
df_portrait_less
# Out:
#      numero_cluster                                       manifest_url  \
# 29              258  https://gallica.bnf.fr/iiif/ark:/12148/bpt6k42...
# 45              135  https://digi.ub.uni-heidelberg.de/diglit/iiif/...
# 46              135  https://digi.ub.uni-heidelberg.de/diglit/iiif/...
# 47              135  https://digi.ub.uni-heidelberg.de/diglit/iiif/...
# 48              135  https://digi.ub.uni-heidelberg.de/diglit/iiif/...
# 49              135  https://digi.ub.uni-heidelberg.de/diglit/iiif/...
# 50              135  https://digi.ub.uni-heidelberg.de/diglit/iiif/...
# 51              135  https://gallica.bnf.fr/iiif/ark:/12148/bpt6k42...
# 52              135  https://gallica.bnf.fr/iiif/ark:/12148/bpt6k61...
# 53              135  https://gallica.bnf.fr/iiif/ark:/12148/bpt6k30...
# 54              135  https://gallica.bnf.fr/iiif/ark:/12148/bpt6k42...
# 55              135  https://iiif.archivelab.org/iiif/sim_arts-maga...
# 56              135  https://iiif.archivelab.org/iiif/sim_arts-maga...
# 57              135  https://iiif.archivelab.org/iiif/sim_arts-maga...
# 58              270  https://gallica.bnf.fr/iiif/ark:/12148/bpt6k42...
# 59              136  https://digi.ub.uni-heidelberg.de/diglit/iiif/...
# 60              136  https://digi.ub.uni-heidelberg.de/diglit/iiif/...
# 61              136  https://digi.ub.uni-heidelberg.de/diglit/iiif/...
# 62              136  https://gallica.bnf.fr/iiif/ark:/12148/bpt6k61...
# 63              136  https://gallica.bnf.fr/iiif/ark:/12148/bpt6k42...
# 64              136  https://gallica.bnf.fr/iiif/ark:/12148/bpt6k42...
# 93              282  https://iiif.unige.ch/dhportal/ug8025333/manifest
# 98              250  https://digi.ub.uni-heidelberg.de/diglit/iiif/...
# 109             262  https://gallica.bnf.fr/iiif/ark:/12148/bpt6k42...
# 110             265  https://digi.ub.uni-heidelberg.de/diglit/iiif/...
# 111             265  https://digi.ub.uni-heidelberg.de/diglit/iiif/...
# 112             265  https://gallica.bnf.fr/iiif/ark:/12148/bpt6k42...
# 113             265  https://gallica.bnf.fr/iiif/ark:/12148/bpt6k42...
# 114             265  https://gallica.bnf.fr/iiif/ark:/12148/bpt6k61...
# 115             268  https://gallica.bnf.fr/iiif/ark:/12148/bpt6k42...
# 120             289  https://gallica.bnf.fr/iiif/ark:/12148/bpt6k42...
# 121             289  https://gallica.bnf.fr/iiif/ark:/12148/bpt6k97...
# 131             266  https://digi.ub.uni-heidelberg.de/diglit/iiif/...
# 132             266  https://gallica.bnf.fr/iiif/ark:/12148/bpt6k42...
# 139             281  https://digi.ub.uni-heidelberg.de/diglit/iiif/...
# 140             281  https://digi.ub.uni-heidelberg.de/diglit/iiif/...
# 141             281  https://gallica.bnf.fr/iiif/ark:/12148/bpt6k42...
# 142             281  https://iiif.archivelab.org/iiif/sim_carnegie_...
# 144             287  https://digi.ub.uni-heidelberg.de/diglit/iiif/...
# 145             287  https://gallica.bnf.fr/iiif/ark:/12148/bpt6k30...
# 146             287  https://gallica.bnf.fr/iiif/ark:/12148/bpt6k97...
#
#      canvas_number                                          image_url  \
# 29           389.0  https://gallica.bnf.fr/iiif/ark:/12148/bpt6k42...
# 45           262.0  https://digi.ub.uni-heidelberg.de/iiif/2/rhs19...
# 46           305.0  https://digi.ub.uni-heidelberg.de/iiif/2/dkd19...
# 47           338.0  https://digi.ub.uni-heidelberg.de/iiif/2/dkd19...
# 48           501.0  https://digi.ub.uni-heidelberg.de/iiif/2/kunst...
# 49           578.0  https://digi.ub.uni-heidelberg.de/iiif/2/cicer...
# 50           647.0  https://digi.ub.uni-heidelberg.de/iiif/2/cicer...
# 51           143.0  https://gallica.bnf.fr/iiif/ark:/12148/bpt6k42...
# 52            20.0  https://gallica.bnf.fr/iiif/ark:/12148/bpt6k61...
# 53           216.0  https://gallica.bnf.fr/iiif/ark:/12148/bpt6k30...
# 54           247.0  https://gallica.bnf.fr/iiif/ark:/12148/bpt6k42...
# 55             NaN  https://iiif.archivelab.org/iiif/sim_arts-maga...
# 56             NaN  https://iiif.archivelab.org/iiif/sim_arts-maga...
# 57             NaN  https://iiif.archivelab.org/iiif/sim_arts-maga...
# 58           186.0  https://gallica.bnf.fr/iiif/ark:/12148/bpt6k42...
# 59            58.0  https://digi.ub.uni-heidelberg.de/iiif/2/dkd19...
# 60           357.0  https://digi.ub.uni-heidelberg.de/iiif/2/kunst...
# 61           804.0  https://digi.ub.uni-heidelberg.de/iiif/2/cicer...
# 62           131.0  https://gallica.bnf.fr/iiif/ark:/12148/bpt6k61...
# 63           147.0  https://gallica.bnf.fr/iiif/ark:/12148/bpt6k42...
# 64           332.0  https://gallica.bnf.fr/iiif/ark:/12148/bpt6k42...
# 93             0.0  https://iiif.unige.ch/iiif/2/fedora_ug8073947;...
# 98           122.0  https://digi.ub.uni-heidelberg.de/iiif/2/cicer...
# 109          226.0  https://gallica.bnf.fr/iiif/ark:/12148/bpt6k42...
# 110          104.0  https://digi.ub.uni-heidelberg.de/iiif/2/cicer...
# 111          147.0  https://digi.ub.uni-heidelberg.de/iiif/2/samle...
# 112          140.0  https://gallica.bnf.fr/iiif/ark:/12148/bpt6k42...
# 113          224.0  https://gallica.bnf.fr/iiif/ark:/12148/bpt6k42...
# 114            6.0  https://gallica.bnf.fr/iiif/ark:/12148/bpt6k61...
# 115          240.0  https://gallica.bnf.fr/iiif/ark:/12148/bpt6k42...
# 120          276.0  https://gallica.bnf.fr/iiif/ark:/12148/bpt6k42...
# 121          356.0  https://gallica.bnf.fr/iiif/ark:/12148/bpt6k97...
# 131          265.0  https://digi.ub.uni-heidelberg.de/iiif/2/jugen...
# 132          250.0  https://gallica.bnf.fr/iiif/ark:/12148/bpt6k42...
# 139          261.0  https://digi.ub.uni-heidelberg.de/iiif/2/rhs19...
# 140          335.0  https://digi.ub.uni-heidelberg.de/iiif/2/dkd19...
# 141          164.0  https://gallica.bnf.fr/iiif/ark:/12148/bpt6k42...
# 142           17.0  https://iiif.archivelab.org/iiif/sim_carnegie_...
# 144          532.0  https://digi.ub.uni-heidelberg.de/iiif/2/cicer...
# 145          271.0  https://gallica.bnf.fr/iiif/ark:/12148/bpt6k30...
# 146           61.0  https://gallica.bnf.fr/iiif/ark:/12148/bpt6k97...
#
#               City                   Country  \
# 29           Paris                    France
# 45          Warsaw                    Poland
# 46       Stuttgart                   Germany
# 47       Stuttgart                   Germany
# 48          Berlin                   Germany
# 49         Leipzig                   Germany
# 50         Leipzig                   Germany
# 51           Paris                    France
# 52           Paris                    France
# 53           Paris                    France
# 54           Paris                    France
# 55   New York City  United States of America
# 56   New York City  United States of America
# 57   New York City  United States of America
# 58           Paris                    France
# 59       Stuttgart                   Germany
# 60          Berlin                   Germany
# 61         Leipzig                   Germany
# 62           Paris                    France
# 63           Paris                    France
# 64           Paris                    France
# 93       Barcelona                     Spain
# 98         Leipzig                   Germany
# 109          Paris                    France
# 110        Leipzig                   Germany
# 111     Copenhagen                   Denmark
# 112          Paris                    France
# 113          Paris                    France
# 114          Paris                    France
# 115          Paris                    France
# 120          Paris                    France
# 121          Paris                    France
# 131         Munich                   Germany
# 132          Paris                    France
# 139         Warsaw                    Poland
# 140      Stuttgart                   Germany
# 141          Paris                    France
# 142     Pittsburgh  United States of America
# 144        Leipzig                   Germany
# 145          Paris                    France
# 146          Paris                    France
#
#                                     Title  \
# 29                L'Amour de l'art (1920)
# 45                Rocznik Historii Sztuki
# 46          Deutsche Kunst und Dekoration
# 47          Deutsche Kunst und Dekoration
# 48                      Der Kunstwanderer
# 49                           Der Cicerone
# 50                           Der Cicerone
# 51                L'Amour de l'art (1920)
# 52                                 Formes
# 53             L'Art vivant (Paris. 1925)
# 54                  Cahiers d'art (Paris)
# 55                          Arts Magazine
# 56                          Arts Magazine
# 57                          Arts Magazine
# 58                  Cahiers d'art (Paris)
# 59          Deutsche Kunst und Dekoration
# 60                      Der Kunstwanderer
# 61                           Der Cicerone
# 62   Gazette des beaux-arts (Paris. 1859)
# 63                L'Amour de l'art (1920)
# 64                L'Amour de l'art (1920)
# 93                           Revista Nova
# 98                           Der Cicerone
# 109                 Cahiers d'art (Paris)
# 110                          Der Cicerone
# 111                              Samleren
# 112               L'Amour de l'art (1920)
# 113                 Cahiers d'art (Paris)
# 114      Le Bulletin de la vie artistique
# 115                 Cahiers d'art (Paris)
# 120                 Cahiers d'art (Paris)
# 121                 Cahiers d'art (Paris)
# 131                                Jugend
# 132                 Cahiers d'art (Paris)
# 139               Rocznik Historii Sztuki
# 140         Deutsche Kunst und Dekoration
# 141               L'Amour de l'art (1920)
# 142                              Carnegie
# 144                          Der Cicerone
# 145            L'Art vivant (Paris. 1925)
# 146                 Cahiers d'art (Paris)
#
#                                         wkt        Date         Journal Type  \
# 29   POINT(2.3513888888889 48.856944444444)  1924-02-01   Modern Art Journal
# 45          POINT(21.011111111111113 52.23)  1966-01-01          Art History
# 46            POINT(9.1775 48.776111111111)  1912-01-01       Decorative Art
# 47            POINT(9.1775 48.776111111111)  1921-01-01       Decorative Art
# 48   POINT(13.383333333333 52.516666666667)  1927-01-01          Art Journal
# 49                      POINT(12.375 51.34)  1912-01-01   Modern Art Journal
# 50                      POINT(12.375 51.34)  1922-01-01   Modern Art Journal
# 51   POINT(2.3513888888889 48.856944444444)  1937-01-01   Modern Art Journal
# 52   POINT(2.3513888888889 48.856944444444)  1932-01-01   Modern Art Journal
# 53   POINT(2.3513888888889 48.856944444444)  1937-01-01   Modern Art Journal
# 54   POINT(2.3513888888889 48.856944444444)  1947-01-01  Avant-garde Journal
# 55              POINT(-74.006015 40.712728)  1926-01-01          Art Journal
# 56              POINT(-74.006015 40.712728)  1926-01-01          Art Journal
# 57              POINT(-74.006015 40.712728)  1926-01-01          Art Journal
# 58   POINT(2.3513888888889 48.856944444444)  1947-01-01  Avant-garde Journal
# 59            POINT(9.1775 48.776111111111)  1921-01-01       Decorative Art
# 60   POINT(13.383333333333 52.516666666667)  1930-01-01          Art Journal
# 61                      POINT(12.375 51.34)  1912-01-01   Modern Art Journal
# 62   POINT(2.3513888888889 48.856944444444)  1928-01-01          Art Journal
# 63   POINT(2.3513888888889 48.856944444444)  1937-01-01   Modern Art Journal
# 64   POINT(2.3513888888889 48.856944444444)  1926-01-01   Modern Art Journal
# 93           POINT(2.1769444444444 41.3825)  1914-10-08               Humour
# 98                      POINT(12.375 51.34)  1927-01-01   Modern Art Journal
# 109  POINT(2.3513888888889 48.856944444444)  1947-01-01  Avant-garde Journal
# 110                     POINT(12.375 51.34)  1928-01-01   Modern Art Journal
# 111  POINT(12.568888888889 55.676111111111)  1928-01-01          Art History
# 112  POINT(2.3513888888889 48.856944444444)  1937-01-01   Modern Art Journal
# 113  POINT(2.3513888888889 48.856944444444)  1947-01-01  Avant-garde Journal
# 114  POINT(2.3513888888889 48.856944444444)  1923-07-15   Modern Art Journal
# 115  POINT(2.3513888888889 48.856944444444)  1947-01-01  Avant-garde Journal
# 120  POINT(2.3513888888889 48.856944444444)  1947-01-01  Avant-garde Journal
# 121  POINT(2.3513888888889 48.856944444444)  1927-01-01  Avant-garde Journal
# 131                   POINT(11.575 48.1375)  1929-01-01   Modern Art Journal
# 132  POINT(2.3513888888889 48.856944444444)  1947-01-01  Avant-garde Journal
# 139         POINT(21.011111111111113 52.23)  1966-01-01          Art History
# 140           POINT(9.1775 48.776111111111)  1921-01-01       Decorative Art
# 141  POINT(2.3513888888889 48.856944444444)  1937-01-01   Modern Art Journal
# 142            POINT(-80 40.44166666666667)  1943-02-01         Philanthropy
# 144                     POINT(12.375 51.34)  1926-01-01   Modern Art Journal
# 145  POINT(2.3513888888889 48.856944444444)  1938-01-01   Modern Art Journal
# 146  POINT(2.3513888888889 48.856944444444)  1932-01-01  Avant-garde Journal
#
#      notice                                         group_name group_tags  \
# 29      NaN                          VanGogh_ItalianWoman_1887   Portrait
# 45      NaN                            VanGogh_Arlesienne_1888   Portrait
# 46      NaN                            VanGogh_Arlesienne_1888   Portrait
# 47      NaN                            VanGogh_Arlesienne_1888   Portrait
# 48      NaN                            VanGogh_Arlesienne_1888   Portrait
# 49      NaN                            VanGogh_Arlesienne_1888   Portrait
# 50      NaN                            VanGogh_Arlesienne_1888   Portrait
# 51      NaN                            VanGogh_Arlesienne_1888   Portrait
# 52      NaN                            VanGogh_Arlesienne_1888   Portrait
# 53      NaN                            VanGogh_Arlesienne_1888   Portrait
# 54      NaN                            VanGogh_Arlesienne_1888   Portrait
# 55      NaN                            VanGogh_Arlesienne_1888   Portrait
# 56      NaN                            VanGogh_Arlesienne_1888   Portrait
# 57      NaN                            VanGogh_Arlesienne_1888   Portrait
# 58      NaN              VanGogh_PortraitArtisteSansBarbe_1889   Portrait
# 59      NaN                              VanGogh_DrGachet_1890   Portrait
# 60      NaN                              VanGogh_DrGachet_1890   Portrait
# 61      NaN                              VanGogh_DrGachet_1890   Portrait
# 62      NaN                              VanGogh_DrGachet_1890   Portrait
# 63      NaN                              VanGogh_DrGachet_1890   Portrait
# 64      NaN                              VanGogh_DrGachet_1890   Portrait
# 93      NaN                 VanGogh_PortraitAdelineRavoux_1890   Portrait
# 98      NaN             VanGogh_HeadofPeasantWomanWithCap_1884   Portrait
# 109     NaN               VanGogh_WomanInTheCafeTambourin_1887   Portrait
# 110     NaN                     VanGogh_PortaitPereTanguy_1888   Portrait
# 111     NaN                     VanGogh_PortaitPereTanguy_1888   Portrait
# 112     NaN                     VanGogh_PortaitPereTanguy_1888   Portrait
# 113     NaN                     VanGogh_PortaitPereTanguy_1888   Portrait
# 114     NaN                     VanGogh_PortaitPereTanguy_1888   Portrait
# 115     NaN                                VanGogh_Zouave_1888   Portrait
# 120     NaN                VanGogh_YoungManWithCornflower_1890   Portrait
# 121     NaN                VanGogh_YoungManWithCornflower_1890   Portrait
# 131     NaN                 VanGogh_PorrtaitCamilleRoulin_1888   Portrait
# 132     NaN                 VanGogh_PorrtaitCamilleRoulin_1888   Portrait
# 139     NaN        VanGogh_ArlesiennePortraitMadameGinoux_1890   Portrait
# 140     NaN        VanGogh_ArlesiennePortraitMadameGinoux_1890   Portrait
# 141     NaN        VanGogh_ArlesiennePortraitMadameGinoux_1890   Portrait
# 142     NaN        VanGogh_ArlesiennePortraitMadameGinoux_1890   Portrait
# 144     NaN  VanGogh_YoungPEasantGirlInAStraxHatSittingInFr...   Portrait
# 145     NaN  VanGogh_YoungPEasantGirlInAStraxHatSittingInFr...   Portrait
# 146     NaN  VanGogh_YoungPEasantGirlInAStraxHatSittingInFr...   Portrait
#
#                                 Filename
# 29    8861007808267359747_1924-02-01.jpg
# 45    2727921280430073225_1966-01-01.jpg
# 46   12723693742842148905_1912-01-01.jpg
# 47    5605650274174973682_1921-01-01.jpg
# 48    8854971534209556026_1927-01-01.jpg
# 49    8193669398584550900_1912-01-01.jpg
# 50    4341553720444709626_1922-01-01.jpg
# 51    2166384085171623245_1937-01-01.jpg
# 52   10534432595828564949_1932-01-01.jpg
# 53    2221750040905946975_1937-01-01.jpg
# 54    4203279557831407815_1947-01-01.jpg
# 55   16699326264690741888_1926-01-01.jpg
# 56    3985589603700027241_1926-01-01.jpg
# 57    6016089789330544112_1926-01-01.jpg
# 58   17198757066664151924_1947-01-01.jpg
# 59    1966546017689930770_1921-01-01.jpg
# 60     881873418366666785_1930-01-01.jpg
# 61   12198474087498669377_1912-01-01.jpg
# 62   14270947076500235876_1928-01-01.jpg
# 63   15594523917536520026_1937-01-01.jpg
# 64    3455430818368260423_1926-01-01.jpg
# 93   17002727225545309646_1914-10-08.jpg
# 98   12092641017301758010_1927-01-01.jpg
# 109  16762741219501322896_1947-01-01.jpg
# 110   3781903444428630705_1928-01-01.jpg
# 111  16586066764935691791_1928-01-01.jpg
# 112   2122596887146135925_1937-01-01.jpg
# 113  13274513606033906053_1947-01-01.jpg
# 114  14691511290093773310_1923-07-15.jpg
# 115    169838889892014754_1947-01-01.jpg
# 120  10557942634866141177_1947-01-01.jpg
# 121   8177834103126173014_1927-01-01.jpg
# 131  15220243292037390101_1929-01-01.jpg
# 132  17898751244050429049_1947-01-01.jpg
# 139  13104323162462611673_1966-01-01.jpg
# 140   6950481323937729753_1921-01-01.jpg
# 141    910170732834132017_1937-01-01.jpg
# 142  14042283349472807806_1943-02-01.jpg
# 144   5920090843904859827_1926-01-01.jpg
# 145  14575878468824219134_1938-01-01.jpg
# 146  17081519575713646347_1932-01-01.jpg

# %%
# Enregistrer le tableur

df_portrait_less.to_csv("explore_less.csv")

# %% [markdown]
# ### Viualiser les informations
#
# D'un côté nous avons les informations textuelles et les informations visuelles. Quelles données avons-nous sous la main ?

# %%
df_portrait_less.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 41 entries, 29 to 146
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   numero_cluster  41 non-null     int64
#  1   manifest_url    41 non-null     object
#  2   canvas_number   38 non-null     float64
#  3   image_url       41 non-null     object
#  4   City            41 non-null     object
#  5   Country         41 non-null     object
#  6   Title           41 non-null     object
#  7   wkt             41 non-null     object
#  8   Date            41 non-null     object
#  9   Journal Type    41 non-null     object
#  10  notice          0 non-null      float64
#  11  group_name      41 non-null     object
#  12  group_tags      41 non-null     object
#  13  Filename        41 non-null     object
# dtypes: float64(2), int64(1), object(11)
# memory usage: 4.8+ KB

# %%
df_portrait_less['Date'] = pd.to_datetime(df_portrait_less['Date'])
df_portrait_less.Date.hist()
plt.xticks(rotation =45)
# Out:
# (array([-25567., -21915., -18263., -14610., -10958.,  -7305.,  -3653.,
#              0.]),
#  [Text(-25567.0, 0, '1900'),
#   Text(-21915.0, 0, '1910'),
#   Text(-18263.0, 0, '1920'),
#   Text(-14610.0, 0, '1930'),
#   Text(-10958.0, 0, '1940'),
#   Text(-7305.0, 0, '1950'),
#   Text(-3653.0, 0, '1960'),
#   Text(0.0, 0, '1970')])

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(14, 8))
df_portrait_less.Country.value_counts().plot(kind='bar', color="blue")
plt.title("Pays de reproduction des portraits de Van Gogh")
plt.xlabel('Pays')
plt.ylabel('Compte')
plt.show()

# %%
# exporter les dates
dates = df_portrait_less.Date.value_counts().rename_axis('dates').reset_index(name='counts')
dates['year'] = dates.dates.dt.year
dates.to_csv("explore_dates.csv")

# %%
# exporter les pays
countries = df_portrait_less.Country.value_counts().rename_axis('country').reset_index(name='counts')
countries.to_csv("explore_coutry.csv")
